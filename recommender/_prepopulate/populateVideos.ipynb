# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()
api_key = os.environ['TMDB_API_KEY']

# %%
def trailers(tmdbId):
    response = requests.get(f'https://api.themoviedb.org/3/movie/{tmdbId}/videos?api_key={api_key}')
    return [{'name': result['name'], 'key':result['key']} for result in response.json()['results'] if result['type'] == 'Trailer' and result['site'] == 'YouTube']

trailers(15602)
# Out:
# [{'name': 'Grumpier Old Men - Trailer', 'key': 'rEnOoWs3FuA'}]

# %%
import pandas as pd

df = pd.read_csv('../data/full/links_edited.csv')
df
# Out:
#        movieId   imdbId    tmdbId  movie_idx
# 0            1   114709     862.0        1.0
# 1            2   113497    8844.0        2.0
# 2            3   113228   15602.0        3.0
# 3            4   114885   31357.0        4.0
# 4            5   113041   11862.0        5.0
# ...        ...      ...       ...        ...
# 58093   193876    38566   78251.0    37535.0
# 58094   193878  1754787   87558.0    37536.0
# 58095   193880  5847740  422666.0    37537.0
# 58096   193882  4453756  454439.0    37538.0
# 58097   193886  7606620  540871.0    37539.0
#
# [58098 rows x 4 columns]

# %%
for i, row in df.iterrows():
    try:
        movieId = row['movie_idx']
        tmdbId = row['tmdbId']
        print(movieId, end='\r')
        requests.put(f'http://localhost:3001/movies/{movieId}', json={'trailers': trailers(tmdbId)})
    except Exception as e:
        print(repr(e), row['movie_idx'])
# Out:
# KeyError('results') 604.0
# KeyError('results') 721.0
# KeyError('results') 730.0
# KeyError('results') 769.0
# KeyError('results') 770.0
# KeyError('results') 791.0
# KeyError('results') 8047.0
# KeyError('results') 1133.0
# KeyError('results') 1141.0
# KeyError('results') 1142.0
# KeyError('results') 1155.0
# KeyError('results') 19099.0
# KeyError('results') 1316.0
# KeyError('results') 1421.0
# KeyError('results') 1434.0
# KeyError('results') 1630.0
# KeyError('results') 1736.0
# KeyError('results') 1775.0
# KeyError('results') 1786.0
# KeyError('results') 1827.0
# KeyError('results') 2227.0
# KeyError('results') 2257.0
# KeyError('results') 9988.0
# KeyError('results') 2585.0
# KeyError('results') 2848.0
# KeyError('results') 12094.0
# KeyError('results') 4048.0
# KeyError('results') 4204.0
# KeyError('results') 4565.0
# KeyError('results') 5066.0
# KeyError('results') 5180.0
# KeyError('results') 16884.0
# KeyError('results') 18487.0
# KeyError('results') 5735.0
# ...
